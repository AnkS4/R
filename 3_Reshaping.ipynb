# %%
a <- c(1, 2, 3, 4, 5)
b <- c(11, 12, 13, 14, 15)
c <- cbind(a,b)
c
t(c)
# Out:
#      a b
# [1,] 1 11
# [2,] 2 12
# [3,] 3 13
# [4,] 4 14
# [5,] 5 15
#   [,1] [,2] [,3] [,4] [,5]
# a  1    2    3    4    5
# b 11   12   13   14   15

# %%
d <- read.csv("comb1.csv")
d
# Out:
#    District    Highlighter Marker Pen  Refill
# 1  Ahmednagar  225          51     674  69
# 2  Aurangabad  162         159     755  50
# 3  Buldhana     30          32     616  38
# 4  Dhule       193         390     553  40
# 5  Goa          81         243     518  NA
# 6  Kolhapur    108         118     352  NA
# 7  Mumbai      119         160     391  29
# 8  Nadurbar    162         281     386 156
# 9  Nagpur      107         121     280  33
# 10 Nanded      111         240     761  28
# 11 Nasik       152         239     619  65
# 12 Pune        154         309     768 122
# 13 Raigad      174         436     545  40
# 14 Ratnagiri   326         398    1504  74
# 15 Sangli      121         110     221  47
# 16 Satara       72         156     373  NA
# 17 Sindhudurga  75         217    1253  77
# 18 Solapur     164         160     391  15
# 19 Thane       224         246     733  58

# %%
library(reshape2)
d <- read.csv("Ord_Details.csv")
e <- d[1:10,]
e
melt(e, id=c("Order.ID"))
# Out:
#    Order.ID  Item.ID Qty
# 1  32 90 001 121 021  7
# 2  32 90 001 121 003 49
# 3  32 90 001 121 023  1
# 4  32 90 001 121 018  9
# 5  32 90 001 121 015 29
# 6  32 90 001 121 014 44
# 7  32 90 001 121 001 15
# 8  32 90 001 121 010 25
# 9  32 90 001 121 010 28
# 10 32 90 001 121 024 20
# Warning message:
# “attributes are not identical across measure variables; they will be dropped”
#    Order.ID  variable value
# 1  32 90 001 Item.ID  121 021
# 2  32 90 001 Item.ID  121 003
# 3  32 90 001 Item.ID  121 023
# 4  32 90 001 Item.ID  121 018
# 5  32 90 001 Item.ID  121 015
# 6  32 90 001 Item.ID  121 014
# 7  32 90 001 Item.ID  121 001
# 8  32 90 001 Item.ID  121 010
# 9  32 90 001 Item.ID  121 010
# 10 32 90 001 Item.ID  121 024
# 11 32 90 001 Qty      7
# 12 32 90 001 Qty      49
# 13 32 90 001 Qty      1
# 14 32 90 001 Qty      9
# 15 32 90 001 Qty      29
# 16 32 90 001 Qty      44
# 17 32 90 001 Qty      15
# 18 32 90 001 Qty      25
# 19 32 90 001 Qty      28
# ...

# %%
e <- 1:5
f <- 100:95
g <- rbind(e,f)
g
h <- cbind(e, f)
h
# Out:
# Warning message in rbind(e, f):
# “number of columns of result is not a multiple of vector length (arg 1)”
#   [,1] [,2] [,3] [,4] [,5] [,6]
# e   1   2    3    4    5    1
# f 100  99   98   97   96   95
# Warning message in cbind(e, f):
# “number of rows of result is not a multiple of vector length (arg 1)”
#      e f
# [1,] 1 100
# [2,] 2  99
# [3,] 3  98
# [4,] 4  97
# [5,] 5  96
# [6,] 1  95

# %%
i <- read.csv("Ord_Details.csv")
head(i)
j <- read.csv("Orders.csv")
head(j)
# Out:
#   Order.ID  Item.ID Qty
# 1 32 90 001 121 021  7
# 2 32 90 001 121 003 49
# 3 32 90 001 121 023  1
# 4 32 90 001 121 018  9
# 5 32 90 001 121 015 29
# 6 32 90 001 121 014 44
#   Order.ID  Order.Date Place.of.Shipment Payment.Terms
# 1 32 90 001 31-Dec-10  Pune              Cheque
# 2 32 90 002 6-Jan-11   Nasik             Online
# 3 32 90 003 14-Jan-11  Ahmednagar        Cash
# 4 32 90 004 18-Feb-11  Nanded            Cheque
# 5 32 90 005 19-Feb-11  Kolhapur          Cash
# 6 32 90 006 1-Mar-11   Buldhana          Online

# %%
merge(i, j)
# Out:
#     Order.ID  Item.ID Qty Order.Date Place.of.Shipment Payment.Terms
# 1   32 90 001 121 021  7  31-Dec-10  Pune              Cheque
# 2   32 90 001 121 003 49  31-Dec-10  Pune              Cheque
# 3   32 90 001 121 023  1  31-Dec-10  Pune              Cheque
# 4   32 90 001 121 018  9  31-Dec-10  Pune              Cheque
# 5   32 90 001 121 015 29  31-Dec-10  Pune              Cheque
# 6   32 90 001 121 014 44  31-Dec-10  Pune              Cheque
# 7   32 90 001 121 001 15  31-Dec-10  Pune              Cheque
# 8   32 90 001 121 010 25  31-Dec-10  Pune              Cheque
# 9   32 90 001 121 010 28  31-Dec-10  Pune              Cheque
# 10  32 90 001 121 024 20  31-Dec-10  Pune              Cheque
# 11  32 90 001 121 002  9  31-Dec-10  Pune              Cheque
# 12  32 90 002 121 007 15  6-Jan-11   Nasik             Online
# 13  32 90 002 121 002 44  6-Jan-11   Nasik             Online
# 14  32 90 002 121 014 19  6-Jan-11   Nasik             Online
# ...
