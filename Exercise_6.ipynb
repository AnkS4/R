# %%
df <- read.csv("SingaporeAuto.csv")
boxplot(df$Exp_weights, col=c("Pink"), main="Weights")
# Out:
# Plot with title “Weights”

# %%
boxplot(df$Exp_weights ~ df$VehicleType, col=c(6,3,23,34,45,67,89,100,123,124), main="Weights by Vehicle Types")
# Out:
# Plot with title “Weights by Vehicle Types”

# %%
df <- read.csv("cars2.csv")
plot(df$speed, df$dist, col=c("Pink"), pch=17, xlab = "speed", ylab = "distance")
# Out:
# plot without title
